# %% [markdown]
# # Notebook Test
# _Just something cool I thought I'd try_

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=np.arange(1000)
data=data+np.random.rand(len(data))*19
data=np.sin(data/39)
plt.plot(data,'.')

# %%
count,bins=np.histogram(data,bins=200)
plt.plot(bins[:-1],count,'.-')
